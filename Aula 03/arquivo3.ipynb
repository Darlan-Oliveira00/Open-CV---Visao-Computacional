# %%
import numpy as np

# %%
vetor = np.random.randint(0,200,10)

# %%
vetor
# Out:
# array([147, 172, 120,  19,  96,  35, 132,  53,  61, 108])

# %%
vetor.max()
# Out:
# np.int64(172)

# %%
vetor.argmax()
# Out:
# np.int64(1)

# %%
vetor.min()
# Out:
# np.int64(19)

# %%
vetor.argmin()
# Out:
# np.int64(3)

# %%
vetor.mean()
# Out:
# np.float64(94.3)
