# %%
#Harris Corner Dectecion
#Para identificação de bordas na imagem 
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xadrez = cv2.imread('xadrez.jpg')
xadrez = cv2.cvtColor(xadrez, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(xadrex)

# %%
xadrez_cinza = cv2.cvtColor(xadrez, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(xadrez_cinza, cmap = 'gray')

# %%
xadrez_real = cv2.imread('xadrez_real.jpg')
xadrez_real = cv2.cvtColor(xadrez_real, cv2.COLOR_BGR2RGB)
plt.imshow(xadrez_real)

# %%
cinza_xadrez_real = cv2.cvtColor(xadrez_real, cv2.COLOR_RGB2GRAY)
plt.imshow(cinza_xadrez_real, cmap = 'gray')

# %%
cinza_xadrez_real
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], shape=(463, 800), dtype=uint8)

# %%
xadrez_cinza
# Out:
# array([[71, 49, 51, ..., 55, 55, 55],
#        [29,  4,  4, ...,  0,  0,  0],
#        [32,  5,  4, ...,  6,  6,  6],
#        ...,
#        [36,  0,  4, ...,  0,  0,  0],
#        [36,  0,  4, ...,  0,  0,  0],
#        [36,  0,  4, ...,  0,  0,  0]], shape=(740, 740), dtype=uint8)

# %%
cinza = np.float32(cinza_xadrez_real)

# %%
cinza
# Out:
# array([[71., 49., 51., ..., 55., 55., 55.],
#        [29.,  4.,  4., ...,  0.,  0.,  0.],
#        [32.,  5.,  4., ...,  6.,  6.,  6.],
#        ...,
#        [36.,  0.,  4., ...,  0.,  0.,  0.],
#        [36.,  0.,  4., ...,  0.,  0.,  0.],
#        [36.,  0.,  4., ...,  0.,  0.,  0.]],
#       shape=(740, 740), dtype=float32)

# %%
#Aplicando o Algoritmo Harris Corner Detection
destino = cv2.cornerHarris(src = xadrez_cinza, blockSize = 2, ksize = 3, k = 0.04)

# %%
#Transformação Morfológica pelo cv2.dilate()
destino = cv2.dilate(destino, None)

# %%
xadrez[destino>0.01*destino.max()] = [0,255,0]

# %%
destino.max()
# Out:
# np.float32(0.10344588)

# %%
destino
# Out:
# array([[ 2.9150771e-05,  4.1905430e-05,  4.1905430e-05, ...,
#         -1.3634010e-05, -1.3634010e-05, -1.3634010e-05],
#        [ 4.5196437e-05,  5.8853017e-05,  5.8853017e-05, ...,
#         -1.3634010e-05, -1.3634010e-05, -1.3634010e-05],
#        [ 4.5196437e-05,  5.8853017e-05,  5.8853017e-05, ...,
#          2.3261741e-08, -1.7278219e-09, -3.7840708e-09],
#        ...,
#        [-2.4799292e-06, -2.4799292e-06, -6.0545147e-10, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [-2.4799292e-06, -2.4799292e-06, -6.0545147e-10, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [-2.4799292e-06, -2.4799292e-06, -6.0545147e-10, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#       shape=(740, 740), dtype=float32)

# %%
plt.imshow(xadrez)

# %%
destino = cv2.cornerHarris(src = cinza_xadrez_real, blockSize = 7, ksize = 3, k = 0.04)

# %%
destino = cv2.dilate(destino, None)

# %%
xadrez_real[destino > 0.01 * destino.max()] = [255,255,0]

# %%
plt.imshow(xadrez_real)
