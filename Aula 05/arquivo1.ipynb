# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
imagem = cv2.imread('perfil.jpeg')

# %%
type(imagem)
# Out:
# numpy.ndarray

# %%
#RGB
imagem.shape
# Out:
# (1280, 958, 3)

# %%
plt.imshow(imagem)

# %%
#MATHPLOTLIB - Trabalha com o RGB
#Open-cv - trabalha com BGR
corrige_imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(corrige_imagem)

# %%
imagem_escala_cinza = cv2.imread('perfil.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagem_escala_cinza, cmap='gray')

# %%
plt.imshow(imagem_escala_cinza, cmap='magma')
