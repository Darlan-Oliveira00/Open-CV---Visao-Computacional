# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
imagem = cv2.imread('perfil.jpeg')

# %%
plt.imshow(imagem)

# %%
nova_imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nova_imagem)

# %% [markdown]
# nova_imagem.shape

# %%
redimensionada_imagem = cv2.resize(nova_imagem, (640,484))

# %%
plt.imshow(redimensionada_imagem)

# %%
redimensionada_imagem.shape
# Out:
# (484, 640, 3)

# %%
altura = 0.5
largura = 0.5

# %%
outra_imagem = cv2.resize(nova_imagem, (0,0), nova_imagem, altura,largura)

# %%
plt.imshow(outra_imagem)

# %%
imagem_girada = cv2.flip(nova_imagem, 1)

# %%
plt.imshow(imagem_girada)

# %%
cv2.imwrite('perfil.jpeg', imagem)
# Out:
# True

# %%
cv2.imwrite('perfil_girado1.jpeg', imagem_girada)
# Out:
# True

# %%
img = plt.figure(figsize=(10,8))
ax = img.add_subplot(111)
ax.imshow(imagem_girada)
